# %% [markdown]
# Практическая работа №5

# %% [markdown]
# Цель: провести базовый анализ датасета используя такие методы как "head", "shape", "columns", "unique", "sort_values", "drop", "replace", "drop_duplicates", "info", "describe", "loc", "to_csv"

# %%
import pandas as pd 
import numpy as np

starWars = pd.read_csv('star_wars_character_dataset.csv')
starWars.head()
# Out:
#              name  height   mass hair_color   skin_color eye_color  \
# 0  Luke Skywalker   172.0   77.0      blond         fair      blue
# 1           C-3PO   167.0   75.0        NaN         gold    yellow
# 2           R2-D2    96.0   32.0        NaN  white, blue       red
# 3     Darth Vader   202.0  136.0       none        white    yellow
# 4     Leia Organa   150.0   49.0      brown        light     brown
#
#    birth_year     sex     gender homeworld species  \
# 0        19.0    male  masculine  Tatooine   Human
# 1       112.0    none  masculine  Tatooine   Droid
# 2        33.0    none  masculine     Naboo   Droid
# 3        41.9    male  masculine  Tatooine   Human
# 4        19.0  female   feminine  Alderaan   Human
#
#                                                films  \
# 0  The Empire Strikes Back, Revenge of the Sith, ...
# 1  The Empire Strikes Back, Attack of the Clones,...
# 2  The Empire Strikes Back, Attack of the Clones,...
# ...

# %% [markdown]
# 1. Я Дронов Арсений Михайлович вывел начальные данные из своего датасета с этими стобцами  name	height	mass	hair_color	skin_color	eye_color	birth_year	sex	gender	homeworld	species	films	vehicles	starships

# %%
starWars.shape
# Out:
# (87, 14)

# %% [markdown]
# 2. Я Дронов Арсений Михайлович вывел размерность массива через метод Shape

# %%
starWars.columns
# Out:
# Index(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color',
#        'birth_year', 'sex', 'gender', 'homeworld', 'species', 'films',
#        'vehicles', 'starships'],
#       dtype='object')

# %% [markdown]
# 3. Я Дронов Арсений Михайлович вывел все названия колонок из своего датасета
# 'name - имя
# 'height' - Рост
# 'mass' - вес
# 'hair_color' - цвет волос
# 'skin_color' - цвет кожи
# 'eye_color' - цвет глаз
# 'birth_year' - возраст
# 'sex' - пол
# 'gender' - пол
# 'homeworld' - родная планета
# 'species' - раса
# 'films' - фидьмы
# 'vehicles' - транспортное средство
# 'starships' - звездные корабли

# %%
starWars ['sex'].unique()
# Out:
# array(['male', 'none', 'female', 'hermaphroditic', nan], dtype=object)

# %% [markdown]
# 4. Я Дронов Арсений Михайлович вывел все уникальные данные а именно 'male', 'none', 'female', 'hermaphroditic' в стобце 'Sex' c помощью метода Unique

# %%
starWars.sort_values(by = 'name')
# Out:
#                      name  height  mass    hair_color           skin_color  \
# 25                 Ackbar   180.0  83.0          none         brown mottle
# 51             Adi Gallia   184.0  50.0          none                 dark
# 10       Anakin Skywalker   188.0  84.0         blond                 fair
# 27           Arvel Crynyd     NaN   NaN         brown                 fair
# 43            Ayla Secura   178.0  55.0          none                 blue
# ..                    ...     ...   ...           ...                  ...
# 28  Wicket Systri Warrick    88.0  20.0         brown                brown
# 11         Wilhuff Tarkin   180.0   NaN  auburn, grey                 fair
# 53            Yarael Poof   264.0   NaN          none                white
# 18                   Yoda    66.0  17.0         white                green
# 66             Zam Wesell   168.0  55.0        blonde  fair, green, yellow
#
# ...

# %% [markdown]
# 5. Я Дронов Арсений Михайлович отсортировал все данные по именам в алфовитном порядке с помощью метода sort_values

# %%
starWars.drop(columns=['gender'], inplace=True)

# %% [markdown]
# 6. Я Дронов Арсений Михайлович удалил колонку "gender" с помощью метода drop

# %%
starWars = starWars.replace({'starships': np.nan}, 'Unknown')
starWars
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN    unknown      unknown   unknown
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#     birth_year     sex homeworld species  \
# 0         19.0    male  Tatooine   Human
# 1        112.0    none  Tatooine   Droid
# ...

# %% [markdown]
# 7. Я Дронов Арсений Михайлович заменил конкретные данные в колонке 'starships' на Unknown с помощью метода replace

# %%
starWars =starWars.drop_duplicates()
starWars
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN    unknown      unknown   unknown
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#     birth_year     sex homeworld species  \
# 0         19.0    male  Tatooine   Human
# 1        112.0    none  Tatooine   Droid
# ...

# %% [markdown]
# 8. Я Дронов Арсений Михайлович удалил дубликаты в датасете с помощью метода drop_duplicates()

# %%
starWars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        87 non-null     object
#  1   height      81 non-null     float64
#  2   mass        59 non-null     float64
#  3   hair_color  82 non-null     object
#  4   skin_color  87 non-null     object
#  5   eye_color   87 non-null     object
#  6   birth_year  43 non-null     float64
#  7   sex         83 non-null     object
#  8   homeworld   77 non-null     object
#  9   species     83 non-null     object
#  10  films       87 non-null     object
#  11  vehicles    11 non-null     object
#  12  starships   87 non-null     object
# dtypes: float64(3), object(10)
# memory usage: 9.0+ KB

# %% [markdown]
# 9. Я Дронов Арсений Михайлович проанализировал свой датасет с помощью метода info
# - общее количество и названия всех столбцов,
# - количество непустых значений в каждом столбце(например, в столбце mass 59 непустых значений, в столбце vehicles  - 11 непустых значений)
# - тип данных каждого столбца (например, в столбце mass тип данных float64)
# - количество использованной памяти - 9,0+ КБ

# %%
starWars.describe()
# Out:
#            height         mass  birth_year
# count   81.000000    59.000000   43.000000
# mean   174.358025    97.311864   87.565116
# std     34.770429   169.457163  154.691439
# min     66.000000    15.000000    8.000000
# 25%    167.000000    55.600000   35.000000
# 50%    180.000000    79.000000   52.000000
# 75%    191.000000    84.500000   72.000000
# max    264.000000  1358.000000  896.000000

# %% [markdown]
# 10.Я Дронов Арсений Михайлович c помощью метода describe провел статистический числвой анализ :
# - count - количество непустых значений в столбцах - name, mass, birth_year
# - mean - среднее арифметическое значение (сумма всех значений столбца, деленная на количество этих значений)
# - std - стандартное отклонение относительно среднего значения, в столбце height оно небольшое -  34,7, следовательно разброс по данным небольшой, а вот в столбце mass отклонение равно 169,4 - разброс по данным существенно больше
# - min показывает минимальное значение в столбце
# - max аналогично показывает максимальное значение в столбце
# - 25% - первый квартиль (нижний) - значение разделяет самые низкие 25% данных
# - 50% - медиана - значение разделяет данные пополам
# - 75% - третий квартиль (верхний) - значение разделяет самые низкие 75% данных

# %%
starWars1 = starWars.loc[[0, 1, 2 ,3, 4, 5 ],['name', 'height', 'mass']]
starWars1
# Out:
#              name  height   mass
# 0  Luke Skywalker   172.0   77.0
# 1           C-3PO   167.0   75.0
# 2           R2-D2    96.0   32.0
# 3     Darth Vader   202.0  136.0
# 4     Leia Organa   150.0   49.0
# 5       Owen Lars   178.0  120.0

# %% [markdown]
# 11. Я Дронов Арсений Михайлович провел выборку данных по строкам и столбцам с помощью метода loc а именно вывел первые шесть ячейки с данными в таких колонках как: "name", "height", "mass"

# %%
starWars.to_csv("New_starWars.csv", index=True)
starWars
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN    unknown      unknown   unknown
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#     birth_year     sex homeworld species  \
# 0         19.0    male  Tatooine   Human
# 1        112.0    none  Tatooine   Droid
# ...

# %% [markdown]
#  12. Я Дронов Арсений Михайлович сохранил новый датасет при помощи метода to_csv

# %% [markdown]
# Вывод: в ходе практичсекой работы был произведен базовый анализ датасета при помощи таких методов как:  "head", "shape", "columns", "unique", "sort_values", "drop", "replace", "drop_duplicates", "info", "describe", "loc", "to_csv"
